# %%
import pandas as pd
import numpy as np
import seaborn as sns
import mathplotlib,pyplot as plt

# %%
city = pd.read_csv ("C://Users/Diaz Aurelli/Desktop/DataSets/City.csv", sep = ";")
transactions = pd.read_csv ("C://Users/Diaz Aurelli/Desktop/DataSets/Transaction_ID.csv", sep = ";")
cab = pd.read_csv ("C://Users/Diaz Aurelli/Desktop/DataSets/Cab_Data.csv",sep = ";")
customer = pd.read_csv ("C://Users/Diaz Aurelli/Desktop/Datasets/Customer_ID.csv",sep = ";")

# %% [markdown]
# # Cities that the cab companies are operating at

# %%
city
# Out:
#                 City   Population    Users
# 0        NEW YORK NY   8,405,837   302,149
# 1         CHICAGO IL   1,955,130   164,468
# 2     LOS ANGELES CA   1,595,037   144,132
# 3           MIAMI FL   1,339,155    17,675
# 4     SILICON VALLEY   1,177,609    27,247
# 5      ORANGE COUNTY   1,030,185    12,994
# 6       SAN DIEGO CA      959,307   69,995
# 7         PHOENIX AZ      943,999    6,133
# 8          DALLAS TX      942,908   22,157
# 9         ATLANTA GA      814,885   24,701
# 10         DENVER CO      754,233   12,421
# 11         AUSTIN TX      698,371   14,978
# 12        SEATTLE WA      671,238   25,063
# 13         TUCSON AZ      631,442    5,712
# 14  SAN FRANCISCO CA      629,591  213,609
# 15     SACRAMENTO CA      545,776    7,044
# 16     PITTSBURGH PA      542,085    3,643
# 17     WASHINGTON DC      418,859  127,001
# 18      NASHVILLE TN      327,225     9,27
# 19         BOSTON MA      248,968   80,021

# %%
city.shape

# %%
city.columns
# Out:
# Index(['City', 'Population', 'Users'], dtype='object')

# %%
city.isnull().sum()
# Out:
# City          0
# Population    0
# Users         0
# dtype: int64

# %% [markdown]
# # Customer Database

# %%
customer
# Out:
#        Customer ID  Gender  Age  Income (USD/Month)
# 0            29290    Male   28          $10.813,00
# 1            27703    Male   27           $9.237,00
# 2            28712    Male   53          $11.242,00
# 3            28020    Male   23          $23.327,00
# 4            27182    Male   33           $8.536,00
# ...            ...     ...  ...                  ...
# 49166        12490    Male   33          $18.713,00
# 49167        14971    Male   30          $15.346,00
# 49168        41414    Male   38           $3.960,00
# 49169        41677    Male   23          $19.454,00
# 49170        39761  Female   32          $10.128,00
#
# [49171 rows x 4 columns]

# %%
customer.shape
# Out:
# (49171, 4)

# %%
customer.columns
# Out:
# Index(['Customer ID', 'Gender', 'Age', ' Income (USD/Month) '], dtype='object')

# %%
customer.isnull().sum()
# Out:
# Customer ID             0
# Gender                  0
# Age                     0
#  Income (USD/Month)     0
# dtype: int64

# %% [markdown]
# ## Transactions Database

# %%
transactions
# Out:
#         Transaction ID  Customer ID Payment_Mode
# 0             10000011        29290         Card
# 1             10000012        27703         Card
# 2             10000013        28712         Cash
# 3             10000014        28020         Cash
# 4             10000015        27182         Card
# ...                ...          ...          ...
# 440093        10440104        53286         Cash
# 440094        10440105        52265         Cash
# 440095        10440106        52175         Card
# 440096        10440107        52917         Card
# 440097        10440108        51587         Card
#
# [440098 rows x 3 columns]

# %%
transactions.shape
# Out:
# (440098, 3)

# %%
transaction.columns
# Out:
# Index(['City;Population;Users'], dtype='object')

# %%
transactions.isnull().sum()
# Out:
# Transaction ID    0
# Customer ID       0
# Payment_Mode      0
# dtype: int64

# %% [markdown]
# # Taxi Database

# %%
cab
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 0             10000011     08/01/2016    Pink Cab     ATLANTA GA
# 1             10000012     06/01/2016    Pink Cab     ATLANTA GA
# 2             10000013     02/01/2016    Pink Cab     ATLANTA GA
# 3             10000014     07/01/2016    Pink Cab     ATLANTA GA
# 4             10000015     03/01/2016    Pink Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10440101     08/01/2018  Yellow Cab  WASHINGTON DC
# 359388        10440104     04/01/2018  Yellow Cab  WASHINGTON DC
# 359389        10440105     05/01/2018  Yellow Cab  WASHINGTON DC
# 359390        10440106     05/01/2018  Yellow Cab  WASHINGTON DC
# 359391        10440107     02/01/2018  Yellow Cab  WASHINGTON DC
#
#         KM Travelled   Price Charged   Cost of Trip
# 0              30.45           370.95     313635.00
# 1              28.62           358.52     334854.00
# ...

# %%
cab.shape
# Out:
# (359392, 7)

# %%
cab.columns
# Out:
# Index(['Transaction ID', 'Date of Travel', 'Company', 'City', 'KM Travelled',
#        ' Price Charged ', 'Cost of Trip'],
#       dtype='object')

# %%
cab.isnull().sum()
# Out:
# Transaction ID     0
# Date of Travel     0
# Company            0
# City               0
# KM Travelled       0
#  Price Charged     0
# Cost of Trip       0
# dtype: int64

# %%
cab1 = cab.drop(['Transaction ID','Date of Travel', 'City'], axis=1)

# %%
cab1
# Out:
#            Company  KM Travelled   Price Charged   Cost of Trip
# 0         Pink Cab         30.45           370.95     313635.00
# 1         Pink Cab         28.62           358.52     334854.00
# 2         Pink Cab          9.04           125.20      97632.00
# 3         Pink Cab         33.17           377.40     351602.00
# 4         Pink Cab          8.73           114.62      97776.00
# ...            ...           ...              ...           ...
# 359387  Yellow Cab          4.80            69.24         63.36
# 359388  Yellow Cab          8.40           113.75     106848.00
# 359389  Yellow Cab         27.75           437.07        349.65
# 359390  Yellow Cab          8.80           146.19     114048.00
# 359391  Yellow Cab         12.76           191.58    1776192.00
#
# [359392 rows x 4 columns]

# %% [markdown]
# ### Pairplot

# %%
sns.pairplot(cab1)

# %% [markdown]
# ### Histogram

# %%
sns.displot (cab['KM Travelled'],bins=5)

# %%
sns.displot (cab['Cost of Trip'],bins=5)

# %% [markdown]
# ### Scatterplot

# %%
sns.relplot (x='KM Travelled',y='Cost of Trip',hue='Company',data=cab1)

# %% [markdown]
# ### Box

# %%
sns.catplot ( x='Cost of Trip' , kind = 'box', data = cab1)
